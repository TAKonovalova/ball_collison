# %%
import numpy as np
#import math
#import random
from mpi4py import MPI
import time
import cython

# %%
#global itog
#global v
#global x,y
#global C,C_2,T,C_2_256,T_180
#global itog1
def angle_between(v1,v2):
    dot_pr = v1.dot(v2)
    norms = np.linalg.norm(v1) * np.linalg.norm(v2)
    return np.rad2deg(np.arccos(dot_pr / norms))
def angle_between1(v1,v2):
    dot_pr = v1.dot(v2)
    norms = np.linalg.norm(v1) * np.linalg.norm(v2)
    if np.rad2deg(np.arccos(dot_pr / norms))>90:
        return 180-np.rad2deg(np.arccos(dot_pr / norms))
    else:
        return np.rad2deg(np.arccos(dot_pr / norms))

start=time.time()
collisions=100000000 # N (кол-во соударений в одном тесте)
begin=1 # кол-во тестов в одной параллели (в нашем случае 1)
C=16.0 # половина длины нейтрального элемента (L/2) (считая, что для биллиарда бунимовича это значение 256)
C_2=C*2
C_4=C_2*2
T=np.pi*256
T_180=T*180
C_2_256=C_2+256
C_2_600=C_2+512

comm = MPI.COMM_WORLD
rank = 30+comm.Get_rank()
#print('My rank is ',rank) # выводим номер потока
file_name = 'new_testfirststep{}.txt'.format(rank)
my_file = open(file_name, "w") 
itog=np.array([0,0])
itog1=np.array([0,0,0])
v=np.array([1.1,1.1])
#np.random.seed(rank) 

for i in range (begin):
    fi_i=np.random. random()*2*np.pi #задаем случайный угол для старта 
    print ('My rank is ',rank,' ',fi_i)
    x=256+C #задаем координаты центра
    y=256
    #print (x,y,fi_i/2/np.pi*360)
    for j in range (collisions):
        #print (collisions)
        if (j==0): # вычисляем первое соударение
            if (fi_i<np.arctan(256/C)) or (fi_i>=2*np.pi-np.arctan(256/C)): #попадет ли на правую полуокружность, если да, то вычисляем новые x и y
                k=np.tan(fi_i)
                b=y-k*x
                a=1+k**2
                b1=2*k*b-2*(256+2*C)-2*256*k
                c=(256+2*C)**2+b**2-2*256*b
                if ((-(b1)+np.sqrt(b1**2-4*a*c))/2/a>(256+2*C)):
                    x=((-(b1)+np.sqrt(b1**2-4*a*c))/2/a)
                else:
                    x=((-(b1)-np.sqrt(b1**2-4*a*c))/2/a)
                y=x*k+b
                v=np.array([x-(256+C),y-256]) # вектор перемещения
                r=np.array([(256+2*C)-x,256-y]) # вектор перпендикулярный к касательной в т. соударения 
                v=v-(2*v.dot(r)/(r.dot(r)))*r # отражаем вектор
                fi_i=angle_between1(np.array([x-(256+C),y-256]),r) # вычисляем угол от нормали
                itog1=np.array([x,y,fi_i])
                #itog1=np.vstack([itog1,np.array([x,y,fi_i])]) # записали (координаты и угол)
                #np.savetxt('testfirststep{}.txt'.format(rank),np.array([2*C+angle_between(-r,np.array([0,-1]))/180*np.pi*256,angle_between1(r,v)]))
                my_file.write(str(C_2+angle_between(-r,np.array([0,-1]))/180*np.pi*256)+' '+str(angle_between1(r,v)) +'\n')
                my_file.flush()
		#itog=np.vstack([itog,np.array([2*C+angle_between(-r,np.array([0,-1]))/180*np.pi*256,angle_between1(r,v)])]) # записали (координаты на оси вдоль границы поля и угол)
            elif (np.pi-np.arctan(256/C)>fi_i>=np.arctan(256/C)): #далее по аналогии для остальных частей
                x=(256*2-256+np.tan(fi_i)*(256+C))/np.tan(fi_i)
                y=2*256
                v=np.array([x-(256+C),y-256])
                v[1]=-v[1]
                fi_i=angle_between1(np.array([x-(256+C),y-256]),np.array([0,-1]))
                itog1=np.array([x,y,fi_i])
                #itog1=np.vstack([itog1,np.array([x,y,fi_i])])
                my_file.write(str(C_2_256-x+np.pi*256+2*C)+' '+str(angle_between1(v,np.array([0,-1]))) +'\n')
                my_file.flush()               
		#itog=np.vstack([itog,np.array([256+2*C-x+np.pi*256+2*C,angle_between1(v,np.array([0,-1]))])])
            elif  (np.pi+np.arctan(256/C)<=fi_i<2*np.pi-np.arctan(256/C)):
                x=(-256+np.tan(fi_i)*(256+C))/np.tan(fi_i)
                y=0
                v=np.array([x-(256+C),y-256])
                v[1]=-v[1]
                fi_i=angle_between1(np.array([x-(256+C),y-256]),np.array([0,1]))
                itog1=np.array([x,y,fi_i])
                #itog1=np.vstack([itog1,np.array([x,y,fi_i])])
                my_file.write(str(x-256)+' '+str(angle_between1(v,np.array([0,1]))) +'\n')
                my_file.flush()
                #itog=np.vstack([itog,np.array([x-256,angle_between1(v,np.array([0,1]))])])
            else:
                b=256-np.tan(fi_i)*(256+C)
                k=np.tan(fi_i)
                a=1+k**2
                b1=-2*(256-k*b+256*k)
                c=(b-256)**2
                if ((-(b1)+np.sqrt(b1**2-4*a*c))/2/a<=256):
                    x=((-(b1)+np.sqrt(b1**2-4*a*c))/2/a)
                else:
                    x=((-(b1)-np.sqrt(b1**2-4*a*c))/2/a)
                y=x*k+b
                v=np.array([x-(256+C),y-256])
                r=np.array([256-x,256-y])
                v=v-(2*v.dot(r)/(r.dot(r)))*r
                fi_i=angle_between1(np.array([x-(256+C),y-256]),r)
                itog1=np.array([x,y,fi_i])
                #itog1=np.vstack([itog1,np.array([x,y,fi_i])])
                my_file.write(str((2*C)*2+np.pi*256+angle_between(-r,np.array([0,1]))/180*np.pi*256)+' '+str(angle_between1(r,v)) +'\n')
                my_file.flush()
                #itog=np.vstack([itog,np.array([(2*C)*2+np.pi*256+angle_between(-r,np.array([0,1]))/180*np.pi*256,angle_between1(r,v)])])
        else:
            k=((v[1])/(v[0]))
            b=y-k*x
            divid=b/k
            divid_600=(512-b)/k
            multi=b*k
            if ((C_2_256)>-divid>256) and (round(y,6)!=0): # проверяем попали ли мы в нейтральный элемент (1)
                y=0
                x=-divid
                v[1]=-v[1]
                if (itog1[0]<x): # проверка на то + или - угол между нормалью и частью траектории
                    itog1=np.array([x,y,angle_between1(v,np.array([0,1]))])
                    #itog1=np.vstack([itog1,np.array([x,y,angle_between1(v,np.array([0,1]))])])
                    my_file.write(str(x-256)+' '+str(angle_between1(v,np.array([0,1]))) +'\n')
                    my_file.flush()
                    #itog=np.vstack([itog,np.array([x-256,angle_between1(v,np.array([0,1]))])])

                else:
                    itog1=np.array([x,y,-angle_between1(v,np.array([0,1]))])
                    #itog1=np.vstack([itog1,np.array([x,y,-angle_between1(v,np.array([0,1]))])])
                    my_file.write(str(x-256)+' '+str(-angle_between1(v,np.array([0,1]))) +'\n')
                    my_file.flush()
                    #itog=np.vstack([itog,np.array([x-256,-angle_between1(v,np.array([0,1]))])])


            elif ((C_2_256)>divid_600>256) and (512!=round(y,6)): # аналогично
                y=512
                x=divid_600
                v[1]=-v[1]
                if(itog1[0]<x):
                    itog1=np.array([x,y,-angle_between1(v,np.array([0,-1]))])
                    #itog1=np.vstack([itog1,np.array([x,y,-angle_between1(v,np.array([0,-1]))])])
                    my_file.write(str(256+C_2-x+np.pi*256+2*C)+' '+str(-angle_between1(v,np.array([0,-1]))) +'\n')
                    my_file.flush()
                    #itog=np.vstack([itog,np.array([C_2_256-x+T+C_2,-angle_between1(v,np.array([0,-1]))])])

                else:
                    itog1=np.array([x,y,angle_between1(v,np.array([0,-1]))])
                    #itog1=np.vstack([itog1,np.array([x,y,angle_between1(v,np.array([0,-1]))])])
                    my_file.write(str(256+C_2-x+np.pi*256+C_2)+' '+str(angle_between1(v,np.array([0,-1]))) +'\n')
                    my_file.flush()
                    #itog=np.vstack([itog,np.array([C_2_256-x+T+C_2,angle_between1(v,np.array([0,-1]))])])

            else:# вычисления для соударений с выпуклой частью
                d=(4*(256-multi+256*k)**2-4*(1+k**2)*(b-256)**2)
                x1=0
                x2=0
                if (d>=0):
                    x1=(2*(256-multi+256*k)+np.sqrt(d))/2/(1+k**2)
                    x2=(2*(256-multi+256*k)-np.sqrt(d))/2/(1+k**2)
                else:
                    d=-1       
                if (d>=0)and(((0<x1<=256) and (round(x,6)!=round(x1,6))) or ((0<x2<=256) and (round(x,6)!=round(x2,6)))):
                        if ((0<x1<=256) and (round(x,6)!=round(x1,6))):
                            x=x1
                            y=k*x+b
                            r=np.array([256-x,256-y])
                            v=v-(2*v.dot(r)/(r.dot(r)))*r
                            if (y<itog1[1]):
                                itog1=np.array([x,y,angle_between1(r,v)])
                                #itog1=np.vstack([itog1,np.array([x,y,angle_between1(r,v)])])
                                my_file.write(str(C_4+np.pi*256+angle_between(-r,np.array([0,1]))/180*np.pi*256)+' '+str(angle_between1(r,v)) +'\n')
                                my_file.flush()
                                #itog=np.vstack([itog,np.array([C_4+T+angle_between(-r,np.array([0,1]))/T_180,angle_between1(r,v)])])

                            else:
                                itog1=np.array([x,y,-angle_between1(r,v)])
                                #itog1=np.vstack([itog1,np.array([x,y,-angle_between1(r,v)])])
                                my_file.write(str(C_4+np.pi*256+angle_between(-r,np.array([0,1]))/180*np.pi*256)+' '+str(-angle_between1(r,v)) +'\n')
                                my_file.flush()
                                #itog=np.vstack([itog,np.array([C_4+T+angle_between(-r,np.array([0,1]))/T_180,-angle_between1(r,v)])])

                        else:
                            x=x2
                            y=k*x+b
                            r=np.array([256-x,256-y])
                            v=v-(2*v.dot(r)/(r.dot(r)))*r
                            if (y<itog1[1]):
                                itog1=np.array([x,y,angle_between1(r,v)])
                                #itog1=np.vstack([itog1,np.array([x,y,angle_between1(r,v)])])
                                my_file.write(str(C_4+np.pi*256+angle_between(-r,np.array([0,1]))/180*np.pi*256)+' '+str(angle_between1(r,v)) +'\n')
                                my_file.flush()
                                #itog=np.vstack([itog,np.array([C_4+T+angle_between(-r,np.array([0,1]))/T_180,angle_between1(r,v)])])

                            else:
                                itog1=np.array([x,y,-angle_between1(r,v)])
                                #itog1=np.vstack([itog1,np.array([x,y,-angle_between1(r,v)])])
                                my_file.write(str(C_4+np.pi*256+angle_between(-r,np.array([0,1]))/180*np.pi*256)+' '+str(-angle_between1(r,v)) +'\n')
                                my_file.flush()
                                #itog=np.vstack([itog,np.array([C_4+T+angle_between(-r,np.array([0,1]))/T_180,-angle_between1(r,v)])])

                    
                else:
                    d=4*(multi-(C_2_256)-256*k)**2-4*(1+k**2)*((C_2_256)**2+b**2-512*b)
                    if (d>=0):
                        x1=-(2*(multi-(C_2_256)-256*k)+np.sqrt(d))/2/(1+k**2)
                        x2=-(2*(multi-(C_2_256)-256*k)-np.sqrt(d))/2/(1+k**2)
                    else:
                        d=-1
                    if (d>=0)and((((C_2_256)<x1<=(C_2_600)) and (round(x,6)!=round(x1,6))) or (((C_2_256)<x2<=(C_2_600)) and (round(x,6)!=round(x2,6)))):
                        if (((C_2_256)<x1<=(C_2_600)) and (round(x,6)!=round(x1,6))):
                            x=x1
                            y=k*x+b
                            r=np.array([(C_2_256)-x,256-y])
                            v=v-(2*v.dot(r)/(r.dot(r)))*r
                            if(y<itog1[1]):
                                itog1=np.array([x,y,-angle_between1(r,v)])
                                #itog1=np.vstack([itog1,np.array([x,y,-angle_between1(r,v)])])
                                my_file.write(str(C_2+angle_between(-r,np.array([0,-1]))/180*np.pi*256)+' '+str(-angle_between1(r,v)) +'\n')
                                my_file.flush()
                                #itog=np.vstack([itog,np.array([C_2+angle_between(-r,np.array([0,-1]))/T_180,-angle_between1(r,v)])])

                            else:
                                itog1=np.array([x,y,angle_between1(r,v)])
                                #itog1=np.vstack([itog1,np.array([x,y,angle_between1(r,v)])])
                                my_file.write(str(C_2+angle_between(-r,np.array([0,-1]))/180*np.pi*256)+' '+str(angle_between1(r,v)) +'\n')
                                my_file.flush()
                                #itog=np.vstack([itog,np.array([C_2+angle_between(-r,np.array([0,-1]))/T_180,angle_between1(r,v)])])

                        else:
                            x=x2
                            y=k*x+b
                            r=np.array([(C_2_256)-x,256-y])
                            v=v-(2*v.dot(r)/(r.dot(r)))*r
                            if(y<itog1[1]):
                                itog1=np.array([x,y,-angle_between1(r,v)])
                                #itog1=np.vstack([itog1,np.array([x,y,-angle_between1(r,v)])])
                                my_file.write(str((C_2)+angle_between(-r,np.array([0,-1]))/180*np.pi*256)+' '+str(-angle_between1(r,v)) +'\n')
                                my_file.flush()
                                #itog=np.vstack([itog,np.array([(C_2)+angle_between(-r,np.array([0,-1]))/T_180,-angle_between1(r,v)])])

                            else:
                                itog1=np.array([x,y,angle_between1(r,v)])
                                #itog1=np.vstack([itog1,np.array([x,y,angle_between1(r,v)])])
                                my_file.write(str((C_2)+angle_between(-r,np.array([0,-1]))/180*np.pi*256)+' '+str(angle_between1(r,v)) +'\n')
                                my_file.flush()
                                #itog=np.vstack([itog,np.array([(C_2)+angle_between(-r,np.array([0,-1]))/T_180,angle_between1(r,v)])])
                    else:
                        #my_file.write('1111111111111111111111111111111111111111111111111111111111111\n')
                        #my_file.flush()
                        k=((v[1])/(v[0]))
                        b=y-k*x
                        divid=b/k
                        divid_600=(512-b)/k
                        multi=b*k
                        if ((C_2_256)>-divid>256) and (round(y,7)!=0): # проверяем попали ли мы в нейтральный элемент (1)
                            y=0
                            x=-divid
                            v[1]=-v[1]
                            if (itog1[0]<x): # проверка на то + или - угол между нормалью и частью траектории
                                itog1=np.array([x,y,angle_between1(v,np.array([0,1]))])
                                #itog1=np.vstack([itog1,np.array([x,y,angle_between1(v,np.array([0,1]))])])
                                my_file.write(str(x-256)+' '+str(angle_between1(v,np.array([0,1]))) +'\n')
                                my_file.flush()
                                #itog=np.vstack([itog,np.array([x-256,angle_between1(v,np.array([0,1]))])])

                            else:
                                itog1=np.array([x,y,-angle_between1(v,np.array([0,1]))])
                                #itog1=np.vstack([itog1,np.array([x,y,-angle_between1(v,np.array([0,1]))])])
                                my_file.write(str(x-256)+' '+str(-angle_between1(v,np.array([0,1]))) +'\n')
                                my_file.flush()
                                #itog=np.vstack([itog,np.array([x-256,-angle_between1(v,np.array([0,1]))])])


                        elif ((C_2_256)>divid_600>256) and (512!=round(y,7)): # аналогично
                            y=512
                            x=divid_600
                            v[1]=-v[1]
                            if(itog1[0]<x):
                                itog1=np.array([x,y,-angle_between1(v,np.array([0,-1]))])
                                #itog1=np.vstack([itog1,np.array([x,y,-angle_between1(v,np.array([0,-1]))])])
                                my_file.write(str(256+C_2-x+np.pi*256+2*C)+' '+str(-angle_between1(v,np.array([0,-1]))) +'\n')
                                my_file.flush()
                                #itog=np.vstack([itog,np.array([C_2_256-x+T+C_2,-angle_between1(v,np.array([0,-1]))])])

                            else:
                                itog1=np.array([x,y,angle_between1(v,np.array([0,-1]))])
                                #itog1=np.vstack([itog1,np.array([x,y,angle_between1(v,np.array([0,-1]))])])
                                my_file.write(str(256+C_2-x+np.pi*256+C_2)+' '+str(angle_between1(v,np.array([0,-1]))) +'\n')
                                my_file.flush()
                                #itog=np.vstack([itog,np.array([C_2_256-x+T+C_2,angle_between1(v,np.array([0,-1]))])])

                        else:# вычисления для соударений с выпуклой частью
                            d=(4*(256-multi+256*k)**2-4*(1+k**2)*(b-256)**2)
                            x1=0
                            x2=0
                            if (d>=0):
                                x1=(2*(256-multi+256*k)+np.sqrt(d))/2/(1+k**2)
                                x2=(2*(256-multi+256*k)-np.sqrt(d))/2/(1+k**2)
                            else:
                                d=-1       
                            if (d>=0)and(((0<x1<=256) and (round(x,7)!=round(x1,7))) or ((0<x2<=256) and (round(x,7)!=round(x2,7)))):
                                    if ((0<x1<=256) and (round(x,7)!=round(x1,7))):
                                        x=x1
                                        y=k*x+b
                                        r=np.array([256-x,256-y])
                                        v=v-(2*v.dot(r)/(r.dot(r)))*r
                                        if (y<itog1[1]):
                                            itog1=np.array([x,y,angle_between1(r,v)])
                                            #itog1=np.vstack([itog1,np.array([x,y,angle_between1(r,v)])])
                                            my_file.write(str(C_4+np.pi*256+angle_between(-r,np.array([0,1]))/180*np.pi*256)+' '+str(angle_between1(r,v)) +'\n')
                                            my_file.flush()
                                            #itog=np.vstack([itog,np.array([C_4+T+angle_between(-r,np.array([0,1]))/T_180,angle_between1(r,v)])])

                                        else:
                                            itog1=np.array([x,y,-angle_between1(r,v)])
                                            #itog1=np.vstack([itog1,np.array([x,y,-angle_between1(r,v)])])
                                            my_file.write(str(C_4+np.pi*256+angle_between(-r,np.array([0,1]))/180*np.pi*256)+' '+str(-angle_between1(r,v)) +'\n')
                                            my_file.flush()
                                            #itog=np.vstack([itog,np.array([C_4+T+angle_between(-r,np.array([0,1]))/T_180,-angle_between1(r,v)])])

                                    else:
                                        x=x2
                                        y=k*x+b
                                        r=np.array([256-x,256-y])
                                        v=v-(2*v.dot(r)/(r.dot(r)))*r
                                        if (y<itog1[1]):
                                            itog1=np.array([x,y,angle_between1(r,v)])
                                            #itog1=np.vstack([itog1,np.array([x,y,angle_between1(r,v)])])
                                            my_file.write(str(C_4+np.pi*256+angle_between(-r,np.array([0,1]))/180*np.pi*256)+' '+str(angle_between1(r,v)) +'\n')
                                            my_file.flush()
                                            #itog=np.vstack([itog,np.array([C_4+T+angle_between(-r,np.array([0,1]))/T_180,angle_between1(r,v)])])

                                        else:
                                            itog1=np.array([x,y,-angle_between1(r,v)])
                                            #itog1=np.vstack([itog1,np.array([x,y,-angle_between1(r,v)])])
                                            my_file.write(str(C_4+np.pi*256+angle_between(-r,np.array([0,1]))/180*np.pi*256)+' '+str(-angle_between1(r,v)) +'\n')
                                            my_file.flush()
                                            #itog=np.vstack([itog,np.array([C_4+T+angle_between(-r,np.array([0,1]))/T_180,-angle_between1(r,v)])])

                                
                            else:
                                d=4*(multi-(C_2_256)-256*k)**2-4*(1+k**2)*((C_2_256)**2+b**2-512*b)
                                if (d>=0):
                                    x1=-(2*(multi-(C_2_256)-256*k)+np.sqrt(d))/2/(1+k**2)
                                    x2=-(2*(multi-(C_2_256)-256*k)-np.sqrt(d))/2/(1+k**2)
                                else:
                                    d=-1
                                if (d>=0)and((((C_2_256)<x1<=(C_2_600)) and (round(x,7)!=round(x1,7))) or (((C_2_256)<x2<=(C_2_600)) and (round(x,7)!=round(x2,7)))):
                                    if (((C_2_256)<x1<=(C_2_600)) and (round(x,7)!=round(x1,7))):
                                        x=x1
                                        y=k*x+b
                                        r=np.array([(C_2_256)-x,256-y])
                                        v=v-(2*v.dot(r)/(r.dot(r)))*r
                                        if(y<itog1[1]):
                                            itog1=np.array([x,y,-angle_between1(r,v)])
                                            #itog1=np.vstack([itog1,np.array([x,y,-angle_between1(r,v)])])
                                            my_file.write(str(C_2+angle_between(-r,np.array([0,-1]))/180*np.pi*256)+' '+str(-angle_between1(r,v)) +'\n')
                                            my_file.flush()
                                            #itog=np.vstack([itog,np.array([C_2+angle_between(-r,np.array([0,-1]))/T_180,-angle_between1(r,v)])])

                                        else:
                                            itog1=np.array([x,y,angle_between1(r,v)])
                                            #itog1=np.vstack([itog1,np.array([x,y,angle_between1(r,v)])])
                                            my_file.write(str(C_2+angle_between(-r,np.array([0,-1]))/180*np.pi*256)+' '+str(angle_between1(r,v)) +'\n')
                                            my_file.flush()
                                            #itog=np.vstack([itog,np.array([C_2+angle_between(-r,np.array([0,-1]))/T_180,angle_between1(r,v)])])

                                    else:
                                        x=x2
                                        y=k*x+b
                                        r=np.array([(C_2_256)-x,256-y])
                                        v=v-(2*v.dot(r)/(r.dot(r)))*r
                                        if(y<itog1[1]):
                                            itog1=np.array([x,y,-angle_between1(r,v)])
                                            #itog1=np.vstack([itog1,np.array([x,y,-angle_between1(r,v)])])
                                            my_file.write(str((C_2)+angle_between(-r,np.array([0,-1]))/180*np.pi*256)+' '+str(-angle_between1(r,v)) +'\n')
                                            my_file.flush()
                                            #itog=np.vstack([itog,np.array([(C_2)+angle_between(-r,np.array([0,-1]))/T_180,-angle_between1(r,v)])])

                                        else:
                                            itog1=np.array([x,y,angle_between1(r,v)])
                                            #itog1=np.vstack([itog1,np.array([x,y,angle_between1(r,v)])])
                                            my_file.write(str((C_2)+angle_between(-r,np.array([0,-1]))/180*np.pi*256)+' '+str(angle_between1(r,v)) +'\n')
                                            my_file.flush()
                                            #itog=np.vstack([itog,np.array([(C_2)+angle_between(-r,np.array([0,-1]))/T_180,angle_between1(r,v)])])
                                else:
                                    #my_file.write('11111111111111111111111111111111111111111111111111111\n')
                                    #my_file.flush()
                                    k=((v[1])/(v[0]))
                                    b=y-k*x
                                    divid=b/k
                                    divid_600=(512-b)/k
                                    multi=b*k
                                    if ((C_2_256)>-divid>256) and (round(y,8)!=0): # проверяем попали ли мы в нейтральный элемент (1)
                                        y=0
                                        x=-divid
                                        v[1]=-v[1]
                                        if (itog1[0]<x): # проверка на то + или - угол между нормалью и частью траектории
                                            itog1=np.array([x,y,angle_between1(v,np.array([0,1]))])
                                            #itog1=np.vstack([itog1,np.array([x,y,angle_between1(v,np.array([0,1]))])])
                                            my_file.write(str(x-256)+' '+str(angle_between1(v,np.array([0,1]))) +'\n')
                                            my_file.flush()
                                            #itog=np.vstack([itog,np.array([x-256,angle_between1(v,np.array([0,1]))])])

                                        else:
                                            itog1=np.array([x,y,-angle_between1(v,np.array([0,1]))])
                                            #itog1=np.vstack([itog1,np.array([x,y,-angle_between1(v,np.array([0,1]))])])
                                            my_file.write(str(x-256)+' '+str(-angle_between1(v,np.array([0,1]))) +'\n')
                                            my_file.flush()
                                            #itog=np.vstack([itog,np.array([x-256,-angle_between1(v,np.array([0,1]))])])


                                    elif ((C_2_256)>divid_600>256) and (512!=round(y,8)): # аналогично
                                        y=512
                                        x=divid_600
                                        v[1]=-v[1]
                                        if(itog1[0]<x):
                                            itog1=np.array([x,y,-angle_between1(v,np.array([0,-1]))])
                                            #itog1=np.vstack([itog1,np.array([x,y,-angle_between1(v,np.array([0,-1]))])])
                                            my_file.write(str(256+C_2-x+np.pi*256+2*C)+' '+str(-angle_between1(v,np.array([0,-1]))) +'\n')
                                            my_file.flush()
                                            #itog=np.vstack([itog,np.array([C_2_256-x+T+C_2,-angle_between1(v,np.array([0,-1]))])])

                                        else:
                                            itog1=np.array([x,y,angle_between1(v,np.array([0,-1]))])
                                            #itog1=np.vstack([itog1,np.array([x,y,angle_between1(v,np.array([0,-1]))])])
                                            my_file.write(str(256+C_2-x+np.pi*256+C_2)+' '+str(angle_between1(v,np.array([0,-1]))) +'\n')
                                            my_file.flush()
                                            #itog=np.vstack([itog,np.array([C_2_256-x+T+C_2,angle_between1(v,np.array([0,-1]))])])

                                    else:# вычисления для соударений с выпуклой частью
                                        d=(4*(256-multi+256*k)**2-4*(1+k**2)*(b-256)**2)
                                        x1=0
                                        x2=0
                                        if (d>=0):
                                            x1=(2*(256-multi+256*k)+np.sqrt(d))/2/(1+k**2)
                                            x2=(2*(256-multi+256*k)-np.sqrt(d))/2/(1+k**2)
                                        else:
                                            d=-1       
                                        if (d>=0)and(((0<x1<=256) and (round(x,8)!=round(x1,8))) or ((0<x2<=256) and (round(x,8)!=round(x2,8)))):
                                                if ((0<x1<=256) and (round(x,8)!=round(x1,8))):
                                                    x=x1
                                                    y=k*x+b
                                                    r=np.array([256-x,256-y])
                                                    v=v-(2*v.dot(r)/(r.dot(r)))*r
                                                    if (y<itog1[1]):
                                                        itog1=np.array([x,y,angle_between1(r,v)])
                                                        #itog1=np.vstack([itog1,np.array([x,y,angle_between1(r,v)])])
                                                        my_file.write(str(C_4+np.pi*256+angle_between(-r,np.array([0,1]))/180*np.pi*256)+' '+str(angle_between1(r,v)) +'\n')
                                                        my_file.flush()
                                                        #itog=np.vstack([itog,np.array([C_4+T+angle_between(-r,np.array([0,1]))/T_180,angle_between1(r,v)])])

                                                    else:
                                                        itog1=np.array([x,y,-angle_between1(r,v)])
                                                        #itog1=np.vstack([itog1,np.array([x,y,-angle_between1(r,v)])])
                                                        my_file.write(str(C_4+np.pi*256+angle_between(-r,np.array([0,1]))/180*np.pi*256)+' '+str(-angle_between1(r,v)) +'\n')
                                                        my_file.flush()
                                                        #itog=np.vstack([itog,np.array([C_4+T+angle_between(-r,np.array([0,1]))/T_180,-angle_between1(r,v)])])

                                                else:
                                                    x=x2
                                                    y=k*x+b
                                                    r=np.array([256-x,256-y])
                                                    v=v-(2*v.dot(r)/(r.dot(r)))*r
                                                    if (y<itog1[1]):
                                                        itog1=np.array([x,y,angle_between1(r,v)])
                                                        #itog1=np.vstack([itog1,np.array([x,y,angle_between1(r,v)])])
                                                        my_file.write(str(C_4+np.pi*256+angle_between(-r,np.array([0,1]))/180*np.pi*256)+' '+str(angle_between1(r,v)) +'\n')
                                                        my_file.flush()
                                                        #itog=np.vstack([itog,np.array([C_4+T+angle_between(-r,np.array([0,1]))/T_180,angle_between1(r,v)])])

                                                    else:
                                                        itog1=np.array([x,y,-angle_between1(r,v)])
                                                        #itog1=np.vstack([itog1,np.array([x,y,-angle_between1(r,v)])])
                                                        my_file.write(str(C_4+np.pi*256+angle_between(-r,np.array([0,1]))/180*np.pi*256)+' '+str(-angle_between1(r,v)) +'\n')
                                                        my_file.flush()
                                                        #itog=np.vstack([itog,np.array([C_4+T+angle_between(-r,np.array([0,1]))/T_180,-angle_between1(r,v)])])

                                            
                                        else:
                                            d=4*(multi-(C_2_256)-256*k)**2-4*(1+k**2)*((C_2_256)**2+b**2-512*b)
                                            if (d>=0):
                                                x1=-(2*(multi-(C_2_256)-256*k)+np.sqrt(d))/2/(1+k**2)
                                                x2=-(2*(multi-(C_2_256)-256*k)-np.sqrt(d))/2/(1+k**2)
                                            else:
                                                d=-1
                                            if (d>=0)and((((C_2_256)<x1<=(C_2_600)) and (round(x,8)!=round(x1,8))) or (((C_2_256)<x2<=(C_2_600)) and (round(x,8)!=round(x2,8)))):
                                                if (((C_2_256)<x1<=(C_2_600)) and (round(x,8)!=round(x1,8))):
                                                    x=x1
                                                    y=k*x+b
                                                    r=np.array([(C_2_256)-x,256-y])
                                                    v=v-(2*v.dot(r)/(r.dot(r)))*r
                                                    if(y<itog1[1]):
                                                        itog1=np.array([x,y,-angle_between1(r,v)])
                                                        #itog1=np.vstack([itog1,np.array([x,y,-angle_between1(r,v)])])
                                                        my_file.write(str(C_2+angle_between(-r,np.array([0,-1]))/180*np.pi*256)+' '+str(-angle_between1(r,v)) +'\n')
                                                        my_file.flush()
                                                        #itog=np.vstack([itog,np.array([C_2+angle_between(-r,np.array([0,-1]))/T_180,-angle_between1(r,v)])])

                                                    else:
                                                        itog1=np.array([x,y,angle_between1(r,v)])
                                                        #itog1=np.vstack([itog1,np.array([x,y,angle_between1(r,v)])])
                                                        my_file.write(str(C_2+angle_between(-r,np.array([0,-1]))/180*np.pi*256)+' '+str(angle_between1(r,v)) +'\n')
                                                        my_file.flush()
                                                        #itog=np.vstack([itog,np.array([C_2+angle_between(-r,np.array([0,-1]))/T_180,angle_between1(r,v)])])

                                                else:
                                                    x=x2
                                                    y=k*x+b
                                                    r=np.array([(C_2_256)-x,256-y])
                                                    v=v-(2*v.dot(r)/(r.dot(r)))*r
                                                    if(y<itog1[1]):
                                                        itog1=np.array([x,y,-angle_between1(r,v)])
                                                        #itog1=np.vstack([itog1,np.array([x,y,-angle_between1(r,v)])])
                                                        my_file.write(str((C_2)+angle_between(-r,np.array([0,-1]))/180*np.pi*256)+' '+str(-angle_between1(r,v)) +'\n')
                                                        my_file.flush()
                                                        #itog=np.vstack([itog,np.array([(C_2)+angle_between(-r,np.array([0,-1]))/T_180,-angle_between1(r,v)])])

                                                    else:
                                                        itog1=np.array([x,y,angle_between1(r,v)])
                                                        #itog1=np.vstack([itog1,np.array([x,y,angle_between1(r,v)])])
                                                        my_file.write(str((C_2)+angle_between(-r,np.array([0,-1]))/180*np.pi*256)+' '+str(angle_between1(r,v)) +'\n')
                                                        my_file.flush()
                                                        #itog=np.vstack([itog,np.array([(C_2)+angle_between(-r,np.array([0,-1]))/T_180,angle_between1(r,v)])])
                                            else:
                                                my_file.write('11111111111111111111111111111111111111111111111111111\n')
                                                my_file.flush()

end=time.time()  
print (end-start) 
my_file.close()
